# %% [markdown]
# # Final Project
# Fall 2018
#
# Xavier Hung
#
# Weiyi Chen

# %% [markdown]
# ### Problem: Do red light cameras result in more speeding in Chicago?

# %% [markdown]
# The red light camera is intended to increase public safety by preventing running a red light, but it that really helpful?
#
# We did a quick research on google and found some articles, most of them state red light camera result in more accidents, and the only purpose of the red light camera is generating millions of revenue for the government. However, according to the Insurance Institute for Highway Safety (IIHS),  fatal accidents caused by speeding can be reduced by up to 19% after the installation of red light cameras.
#
# To verify this statement, we focus on the association between red light cameras and speeding. We will compare the number of speeding that occurred at intersections before and after the use of red light camera to solve this problem.

# %% [markdown]
# ####  data extraction
#
# We extracted data from the City of Chicago, an open data platform. There are four CSV files, red light camera locations, red light camera violations, speed camera locations, and speed camera violations (details of these data can be found at https://data.cityofchicago.org/browse?q=red+light+camera&sortBy=relevance).

# %%
import os
import pandas as pd
import numpy as np
import math
from ast import literal_eval
from bokeh.plotting import figure, show, output_notebook
from bokeh.models.annotations import Title
from bokeh.tile_providers import CARTODBPOSITRON
import warnings
warnings.filterwarnings('ignore')

redlight_loc = pd.read_csv('red-light-camera-locations.csv')
redlight_violations = pd.read_csv('red-light-camera-violations.csv')

speed_loc = pd.read_csv('speed-camera-locations.csv')
speed_violations = pd.read_csv('speed-camera-violations.csv')

##  missing data?

# %% [markdown]
# `speed_loc` and `redlight_loc` have columns, latitude and longitude. We use Mercator projection ???to convert latitude and longitude into coordinates, and plot the locations of red light cameras and speed cameras.

# %%
# plot red light cameras and speed cameras locations
speed_loc["COORDINATES"] = '('+ speed_loc["LATITUDE"].astype(str) +','+ speed_loc["LONGITUDE"].astype(str) + ')'
redlight_loc["COORDINATES"] = '('+ redlight_loc["LATITUDE"].astype(str) +','+ redlight_loc["LONGITUDE"].astype(str) + ')'

def merc(Coords):
    """
    
    
    """
    Coordinates = literal_eval(Coords)
    lat = Coordinates[0]
    lon = Coordinates[1]
    
    r_major = 6378137.000
    x = r_major * math.radians(lon)
    scale = x/lon
    y = 180.0/math.pi * math.log(math.tan(math.pi/4.0 + 
        lat * (math.pi/180.0)/2.0)) * scale
    return (x, y)

speed_loc['coords_x'] = speed_loc['COORDINATES'].apply(lambda x: merc(x)[0])
speed_loc['coords_y'] = speed_loc['COORDINATES'].apply(lambda x: merc(x)[1])

redlight_loc['coords_x'] = redlight_loc['COORDINATES'].apply(lambda x: merc(x)[0])
redlight_loc['coords_y'] = redlight_loc['COORDINATES'].apply(lambda x: merc(x)[1])

p = figure(x_range=(-9790000, -9735000), y_range=(5105000, 5165000),
           x_axis_type="mercator", y_axis_type="mercator")
p.add_tile(CARTODBPOSITRON)

p.circle(x = redlight_loc['coords_x'], y = redlight_loc['coords_y'], legend = "Red Light Camera", fill_color="#FF0000")
p.circle(x = speed_loc['coords_x'], y = speed_loc['coords_y'], legend = "Speed Camera")

t = Title()
t.text = 'Locations of All Speed Cameras and Red Light Cameras'
p.title = t

p.legend.location = "top_right"
p.legend.click_policy="hide"

output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c456e5e3-859f-44cb-bcb0-57d134763f27">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="69b798fa-3d78-4c9d-b699-184f255976d5"></div>
# </div>

# %% [markdown]
# In Chicago, the 0.0001 longitude is about 8 meters when latitudes are same. When longtitude are same, the 0.0001 latitude is about 11 meters.
# link: https://www.movable-type.co.uk/scripts/latlong.html
#
# We are extracting the red light cameras and speed cameras that are near each other by 0.0001 latitude and longitude.

# %%
# redlight_loc_copy is a subset of redlight_loc and contains the locations of red light cameras near speed cameras
# speed_loc_copy is a subset of speed_loc and contains the locations of speed cameras near red light cameras
redlight_loc_copy = pd.DataFrame(columns = redlight_loc.columns.values)
speed_loc_copy = pd.DataFrame(columns = speed_loc.columns.values)

# find red light cameras near speed cameras
for i in range(0,speed_loc.shape[0]):
    for j in range(0,redlight_loc.shape[0]):
        if abs(speed_loc.iloc[i,4] - redlight_loc.iloc[j,5]) < 0.0001 and abs(speed_loc.iloc[i,5] - redlight_loc.iloc[j,6] < 0.0001):
            redlight_loc_copy = redlight_loc_copy.append(redlight_loc.iloc[j], ignore_index = True)
            speed_loc_copy = speed_loc_copy.append(speed_loc.iloc[i], ignore_index = True)

# %%
# change format of addresses in speed_loc_copy to match format of addresses in speed_violations
remove = ["(Speed", "Camera)","Ave","ST","Rd","St","Blvd"]


for i in range(0,speed_loc_copy.shape[0]):
    speed_loc_copy.iloc[i,0] = " ".join([word for word in speed_loc_copy.iloc[i,0].split() if word not in remove])

speed_violations_copy = pd.DataFrame(columns = speed_violations.columns.values)    
    
# subset speed violations where speed cameras are near red light cameras
for i in range(0, speed_loc_copy.shape[0]):
    address = speed_violations[speed_violations['ADDRESS'].str.contains(speed_loc_copy.iloc[i,0].upper())]
    speed_violations_copy = speed_violations_copy.append(address, ignore_index = True)

# %%
redlight_violations_copy = pd.DataFrame(columns = redlight_violations.columns.values)

# subset red light violations where speed cameras are near red light camer
# this will take a while
for i in range (0, redlight_violations.shape[0]):
    for j in range(0, redlight_loc_copy.shape[0]):
        intersection1 = redlight_violations.iloc[i,0].replace(' AND ', '/').replace(' and ', '/').split('/')
        intersection2 = redlight_loc_copy.iloc[j,0].split('-')
        if len(intersection1) > 1 and len(intersection2) > 1:
            if intersection1[0] == intersection2[0].upper() or intersection1[0] == intersection2[1].upper():
                if intersection1[1] == intersection2[0].upper() or intersection1[1] == intersection2[1].upper():
                    redlight_violations_copy = redlight_violations_copy.append(redlight_violations.iloc[i], ignore_index = True)

# %%
speed_loc_copy['coords_x'] = speed_loc_copy['COORDINATES'].apply(lambda x: merc(x)[0])
speed_loc_copy['coords_y'] = speed_loc_copy['COORDINATES'].apply(lambda x: merc(x)[1])

redlight_loc_copy['coords_x'] = redlight_loc_copy['COORDINATES'].apply(lambda x: merc(x)[0])
redlight_loc_copy['coords_y'] = redlight_loc_copy['COORDINATES'].apply(lambda x: merc(x)[1])

p = figure(x_range=(-9780000, -9745000), y_range=(5120000, 5160000),
           x_axis_type="mercator", y_axis_type="mercator")
p.add_tile(CARTODBPOSITRON)

p.circle(x = redlight_loc_copy['coords_x'], y = redlight_loc_copy['coords_y'], legend = "Red Light Camera", fill_color="#FF0000")
p.circle(x = speed_loc_copy['coords_x'], y = speed_loc_copy['coords_y'], legend = "Speed Camera",)

t = Title()
t.text = 'Speed Cameras in Close Proximity to Red Light Cameras'
p.title = t

p.legend.location = "top_right"
p.legend.click_policy="hide"

output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f25ebb55-8045-4e1d-bbf0-0cc215d5222a">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="3f3eb289-db81-49b1-9849-e0665816eaeb"></div>
# </div>

# %%
#find top three intersections with speed cameras nearby that have the most red light violations on a single day
redlight_violations_copy = redlight_violations_copy.sort_values('VIOLATIONS', ascending = False)
redlight_violations_copy.drop_duplicates(subset = 'INTERSECTION', keep = "first").reset_index(drop = True).head()
# Out:
#                                 INTERSECTION  CAMERA ID  \
# 200291                        CICERO AND I55     2251.0
# 395509                 LAKE AND UPPER WACKER     3052.0
# 189548             LAKE SHORE DR AND BELMONT     1413.0
# 180725                        STATE AND 79TH     2654.0
# 320890                 VAN BUREN AND WESTERN     2052.0
# 167405               CALIFORNIA AND DIVERSEY     1514.0
# 181259                     ARCHER AND CICERO     2081.0
# 170697                    LAFAYETTE AND 87TH     2503.0
# 327662                        63RD AND STATE     2714.0
# 171124                WENTWORTH AND GARFIELD     2261.0
# 170756                 COLUMBUS AND ILLINOIS     1951.0
# 11120                 STONEY ISLAND AND 76TH     2632.0
# 129515         STONY ISLAND/CORNELL AND 67TH     2731.0
# 364862                 ROOSEVELT AND HALSTED     2234.0
# 21483                    VINCENNES AND 111TH     2531.0
# 295                        115TH AND HALSTED     2552.0
# 395438                HOLLYWOOD AND SHERIDAN     1344.0
# 311255                  CORTLAND AND ASHLAND     1721.0
# 170773                      99TH AND HALSTED     2431.0
# 20548                  LINCOLN AND MCCORMICK     2751.0
# 23853                     87TH AND VINCENNES     2412.0
# 273967                  HALSTED AND DIVISION     1711.0
# 22759                 CORNELL DRIVE AND 57TH     2182.0
# 388371                    BELMONT AND KEDZIE     1372.0
# 317210                        75TH AND STATE     2624.0
# 182917                     KOSTNER AND NORTH     2013.0
# 184320                   SACRAMENTO AND LAKE     1821.0
# 65508                    LARAMIE AND MADISON     2043.0
# 414880                   ASHLAND AND MADISON     1911.0
# 94435   31ST ST AND MARTIN LUTHER KING DRIVE     2121.0
# ...                                      ...        ...
# 12150                        KEDZIE AND 63RD     2364.0
# 383088                   WESTERN AND CHICAGO     1941.0
# 11454                ASHLAND AND IRVING PARK     1151.0
# 5370                        ASHLAND AND 63RD     2681.0
# 22041                       WESTERN AND 51ST     2172.0
# 409417                  CALIFORNIA AND DEVON     1323.0
# 300725                   SHERIDAN AND FOSTER     1134.0
# 196013                       KEDZIE AND 26TH     2381.0
# 181485                     WESTERN AND DEVON     1212.0
# 21518                       HALSTED AND 63RD     2691.0
# 24013                      ELSTON AND FOSTER     1063.0
# 634                      MADISON AND CENTRAL     1751.0
# 32868                    CLARK AND FULLERTON     1632.0
# 88132                      PULASKI AND NORTH     1994.0
# 183904                   DIVERSEY AND AUSTIN     1454.0
# 178225                       55TH AND KEDZIE     2163.0
# 13455                       JEFFERY AND 79TH     2663.0
# 10080                   PULASKI AND LAWRENCE     1173.0
# 415904          NORTHWEST HIGHWAY AND FOSTER     3002.0
# 187523                   CENTRAL AND ADDISON     1682.0
# 379413                 CENTRAL AND MILWAUKEE     3032.0
# 297005                 CENTRAL AND FULLERTON     1444.0
# 267405                      WESTERN AND 63RD     2371.0
# 29320               HARLEM AND NORTHWEST HWY     1081.0
# 258513                   KIMBALL AND LINCOLN     2741.0
# 19224                       ASHLAND AND 47TH     2192.0
# 385334                   CENTRAL AND BELMONT     1604.0
# 9807                    CENTRAL AND DIVERSEY     1642.0
# 7526                    WESTERN AND ARMITAGE     1861.0
# 22104                   PULASKI AND MONTROSE     1294.0
#
#                         ADDRESS       VIOLATION DATE  VIOLATIONS  \
# 200291     4200 S CICERO AVENUE  2016-10-09T00:00:00         186
# 395509    340 W UPPER WACKER DR  2018-05-27T00:00:00         143
# 189548        400 W BELMONT AVE  2016-08-27T00:00:00         102
# 180725          1 E 79TH STREET  2016-07-23T00:00:00          93
# 320890     400 S WESTERN AVENUE  2017-10-08T00:00:00          90
# 167405          2800 W DIVERSEY  2016-05-22T00:00:00          83
# 181259        5200 S CICERO AVE  2016-07-16T00:00:00          72
# 170697         30 W 87TH STREET  2016-06-11T00:00:00          72
# 327662              1 E 63RD ST  2017-10-29T00:00:00          69
# 171124    5500 S WENTWORTH AVEN  2016-06-11T00:00:00          68
# 170756     500 N COLUMBUS DRIVE  2016-06-11T00:00:00          68
# 11120     7600 S STONY ISLAND A  2014-07-20T00:00:00          68
# 129515     6700 S CORNELL DRIVE  2015-12-20T00:00:00          65
# 364862     800 W ROOSEVELT ROAD  2018-04-01T00:00:00          59
# 21483     11100 S VINCENNES AVE  2014-07-13T00:00:00          54
# 295       11500 S HALSTED STREE  2014-07-05T00:00:00          52
# 395438     1000 W HOLLYWOOD AVE  2018-07-23T00:00:00          51
# 311255       1900 N ASHLAND AVE  2017-09-01T00:00:00          50
# 170773        9900 S HALSTED ST  2016-06-11T00:00:00          49
# 20548     6200 N LINCOLN AVENUE  2014-07-07T00:00:00          46
# 23853          8700 S VINCENNES  2014-07-19T00:00:00          46
# 273967           1200 N HALSTED  2014-08-09T00:00:00          44
# 22759      5700 S CORNELL DRIVE  2014-07-03T00:00:00          43
# 388371        3200 N KEDZIE AVE  2018-06-24T00:00:00          40
# 317210          1 E 75TH STREET  2017-09-24T00:00:00          39
# 182917             4400 W NORTH  2016-07-31T00:00:00          39
# 184320    150 N SACRAMENTO BOUL  2016-08-06T00:00:00          38
# 65508     5200 W MADISON STREET  2015-03-21T00:00:00          38
# 414880          0 N ASHLAND AVE  2018-10-04T00:00:00          38
# 94435   3100 S DR MARTIN L KING  2015-07-23T00:00:00          36
# ...                         ...                  ...         ...
# 12150            3200 W 63RD ST  2014-08-30T00:00:00          11
# 383088        800 N WESTERN AVE  2018-06-08T00:00:00          11
# 11454     4000 N ASHLAND AVENUE  2014-07-31T00:00:00          11
# 5370         6300 S ASHLAND AVE  2014-07-10T00:00:00          11
# 22041       5100 S WESTERN BLVD  2014-08-15T00:00:00          11
# 409417      2800 W DEVON AVENUE  2018-09-14T00:00:00          11
# 300725        1000 W FOSTER AVE  2017-07-23T00:00:00          11
# 196013     2600 S KEDZIE AVENUE  2016-09-22T00:00:00          11
# 181485    6400 N WESTERN AVENUE  2016-07-21T00:00:00          10
# 21518     6300 S HALSTED STREET  2014-07-22T00:00:00          10
# 24013      4932 W FOSTER AVENUE  2014-09-13T00:00:00          10
# 634          0 S CENTRAL AVENUE  2014-08-03T00:00:00          10
# 32868           2400 N CLARK ST  2014-11-08T00:00:00          10
# 88132       4000 W NORTH AVENUE  2015-06-28T00:00:00          10
# 183904   6000 W DIVERSEY AVENUE  2016-08-04T00:00:00           9
# 178225       3200 W 55TH STREET  2016-07-10T00:00:00           9
# 13455        2000 E 79TH STREET  2014-07-26T00:00:00           9
# 10080    4000 W LAWRENCE AVENUE  2014-07-07T00:00:00           9
# 415904     5200 N NORTHWEST HWY  2018-10-08T00:00:00           9
# 187523    3600 N CENTRAL AVENUE  2016-08-19T00:00:00           9
# 379413       5232 N CENTRAL AVE  2018-05-26T00:00:00           9
# 297005   5600 W FULLERTON AVENU  2017-07-08T00:00:00           9
# 267405       6300 S WESTERN AVE  2014-07-19T00:00:00           9
# 29320         6400 N HARLEM AVE  2014-10-25T00:00:00           8
# 258513    6200 N KIMBALL AVENUE  2014-07-24T00:00:00           8
# 19224     4700 S ASHLAND AVENUE  2014-07-06T00:00:00           8
# 385334    5600 W BELMONT AVENUE  2018-06-17T00:00:00           7
# 9807      2800 N CENTRAL AVENUE  2014-07-23T00:00:00           7
# 7526      2000 N WESTERN AVENUE  2014-08-08T00:00:00           7
# 22104    4000 W MONTROSE AVENUE  2014-07-19T00:00:00           6
#
#         X COORDINATE  Y COORDINATE   LATITUDE  LONGITUDE  \
# 200291  1.145024e+06  1.876358e+06  41.816729 -87.743537
# 395509  1.173895e+06  1.901848e+06  41.886082 -87.636870
# 189548  1.172982e+06  1.921577e+06  41.940241 -87.639639
# 180725  1.177680e+06  1.852598e+06  41.750852 -87.624464
# 320890  1.160432e+06  1.898092e+06  41.876065 -87.686416
# 167405  1.157213e+06  1.918527e+06  41.932205 -87.697679
# 181259  1.145196e+06  1.869738e+06  41.798558 -87.743072
# 170697  1.177408e+06  1.847321e+06  41.736376 -87.625621
# 327662  1.177368e+06  1.863199e+06  41.779949 -87.625290
# 171124           NaN           NaN        NaN        NaN
# 170756  1.178373e+06  1.903693e+06  41.891045 -87.620372
# 11120   1.188093e+06  1.854889e+06  41.756897 -87.586234
# 129515  1.188316e+06  1.860851e+06  41.773251 -87.585225
# 364862  1.171199e+06  1.894968e+06  41.867263 -87.646973
# 21483   1.167202e+06  1.831127e+06  41.692161 -87.663472
# 295              NaN           NaN        NaN        NaN
# 395438  1.168580e+06  1.938090e+06  41.985650 -87.655336
# 311255  1.165348e+06  1.912736e+06  41.916147 -87.667947
# 170773  1.172690e+06  1.839172e+06  41.714119 -87.643145
# 20548   1.152551e+06  1.941176e+06  41.994450 -87.714208
# 23853   1.172026e+06  1.847142e+06  41.736007 -87.645342
# 273967  1.170747e+06  1.908242e+06  41.903698 -87.648245
# 22759   1.188166e+06  1.867529e+06  41.791580 -87.585564
# 388371  1.154427e+06  1.921110e+06  41.939352 -87.707847
# 317210  1.177602e+06  1.855229e+06  41.758074 -87.624672
# 182917  1.146739e+06  1.910310e+06  41.909864 -87.736380
# 184320  1.156320e+06  1.900957e+06  41.884012 -87.701436
# 65508   1.141707e+06  1.899568e+06  41.880481 -87.755130
# 414880           NaN           NaN        NaN        NaN
# 94435            NaN           NaN        NaN        NaN
# ...              ...           ...        ...        ...
# 12150   1.156103e+06  1.862718e+06  41.779082 -87.703260
# 383088  1.160221e+06  1.905278e+06  41.895787 -87.686991
# 11454   1.164899e+06  1.926666e+06  41.954379 -87.669199
# 5370    1.166711e+06  1.862904e+06  41.779372 -87.664365
# 22041   1.161346e+06  1.870773e+06  41.801080 -87.683818
# 409417  1.156485e+06  1.942378e+06  41.997670 -87.699706
# 300725  1.168689e+06  1.934759e+06  41.976505 -87.655032
# 196013  1.155404e+06  1.886524e+06  41.844425 -87.705185
# 181485  1.159114e+06  1.942452e+06  41.997818 -87.690033
# 21518   1.172011e+06  1.863049e+06  41.779657 -87.644931
# 24013   1.142394e+06  1.934161e+06  41.975395 -87.751747
# 634              NaN           NaN        NaN        NaN
# 32868   1.172750e+06  1.916239e+06  41.925598 -87.640651
# 88132   1.149456e+06  1.910377e+06  41.909996 -87.726395
# 183904  1.135896e+06  1.918030e+06  41.931249 -87.776029
# 178225  1.155967e+06  1.868016e+06  41.793623 -87.703618
# 13455   1.190923e+06  1.853026e+06  41.751717 -87.575923
# 10080   1.148844e+06  1.931638e+06  41.968351 -87.728092
# 415904  1.137806e+06  1.934042e+06  41.975154 -87.768620
# 187523  1.138343e+06  1.923392e+06  41.945919 -87.766905
# 379413  1.137802e+06  1.934544e+06  41.976532 -87.768622
# 297005  1.138627e+06  1.915439e+06  41.924090 -87.766054
# 267405  1.161416e+06  1.862772e+06  41.779123 -87.683783
# 29320   1.127335e+06  1.941943e+06  41.997019 -87.806948
# 258513  1.152543e+06  1.940954e+06  41.993841 -87.714242
# 19224   1.166424e+06  1.873520e+06  41.808512 -87.665117
# 385334  1.138454e+06  1.920756e+06  41.938684 -87.766562
# 9807    1.138516e+06  1.918089e+06  41.931366 -87.766397
# 7526    1.160007e+06  1.913226e+06  41.917604 -87.687558
# 22104   1.148918e+06  1.928980e+06  41.961056 -87.727891
#
#                                                  LOCATION
# 200291  {'needs_recoding': False, 'longitude': '-87.74...
# 395509  {'needs_recoding': False, 'longitude': '-87.63...
# 189548  {'needs_recoding': False, 'longitude': '-87.63...
# 180725  {'needs_recoding': False, 'longitude': '-87.62...
# 320890  {'needs_recoding': False, 'longitude': '-87.68...
# 167405  {'needs_recoding': False, 'longitude': '-87.69...
# 181259  {'needs_recoding': False, 'longitude': '-87.74...
# 170697  {'needs_recoding': False, 'longitude': '-87.62...
# 327662  {'needs_recoding': False, 'longitude': '-87.62...
# 171124                                                NaN
# 170756  {'needs_recoding': False, 'longitude': '-87.62...
# 11120   {'needs_recoding': False, 'longitude': '-87.58...
# 129515  {'needs_recoding': False, 'longitude': '-87.58...
# 364862  {'needs_recoding': False, 'longitude': '-87.64...
# 21483   {'needs_recoding': False, 'longitude': '-87.66...
# 295                                                   NaN
# 395438  {'needs_recoding': False, 'longitude': '-87.65...
# 311255  {'needs_recoding': False, 'longitude': '-87.66...
# 170773  {'needs_recoding': False, 'longitude': '-87.64...
# 20548   {'needs_recoding': False, 'longitude': '-87.71...
# 23853   {'needs_recoding': False, 'longitude': '-87.64...
# 273967  {'needs_recoding': False, 'longitude': '-87.64...
# 22759   {'needs_recoding': False, 'longitude': '-87.58...
# 388371  {'needs_recoding': False, 'longitude': '-87.70...
# 317210  {'needs_recoding': False, 'longitude': '-87.62...
# 182917  {'needs_recoding': False, 'longitude': '-87.73...
# 184320  {'needs_recoding': False, 'longitude': '-87.70...
# 65508   {'needs_recoding': False, 'longitude': '-87.75...
# 414880                                                NaN
# 94435                                                 NaN
# ...                                                   ...
# 12150   {'needs_recoding': False, 'longitude': '-87.70...
# 383088  {'needs_recoding': False, 'longitude': '-87.68...
# 11454   {'needs_recoding': False, 'longitude': '-87.66...
# 5370    {'needs_recoding': False, 'longitude': '-87.66...
# 22041   {'needs_recoding': False, 'longitude': '-87.68...
# 409417  {'needs_recoding': False, 'longitude': '-87.69...
# 300725  {'needs_recoding': False, 'longitude': '-87.65...
# 196013  {'needs_recoding': False, 'longitude': '-87.70...
# 181485  {'needs_recoding': False, 'longitude': '-87.69...
# 21518   {'needs_recoding': False, 'longitude': '-87.64...
# 24013   {'needs_recoding': False, 'longitude': '-87.75...
# 634                                                   NaN
# 32868   {'needs_recoding': False, 'longitude': '-87.64...
# 88132   {'needs_recoding': False, 'longitude': '-87.72...
# 183904  {'needs_recoding': False, 'longitude': '-87.77...
# 178225  {'needs_recoding': False, 'longitude': '-87.70...
# 13455   {'needs_recoding': False, 'longitude': '-87.57...
# 10080   {'needs_recoding': False, 'longitude': '-87.72...
# 415904  {'needs_recoding': False, 'longitude': '-87.76...
# 187523  {'needs_recoding': False, 'longitude': '-87.76...
# 379413  {'needs_recoding': False, 'longitude': '-87.76...
# 297005  {'needs_recoding': False, 'longitude': '-87.76...
# 267405  {'needs_recoding': False, 'longitude': '-87.68...
# 29320   {'needs_recoding': False, 'longitude': '-87.80...
# 258513  {'needs_recoding': False, 'longitude': '-87.71...
# 19224   {'needs_recoding': False, 'longitude': '-87.66...
# 385334  {'needs_recoding': False, 'longitude': '-87.76...
# 9807    {'needs_recoding': False, 'longitude': '-87.76...
# 7526    {'needs_recoding': False, 'longitude': '-87.68...
# 22104   {'needs_recoding': False, 'longitude': '-87.72...
#
# [183 rows x 10 columns]
